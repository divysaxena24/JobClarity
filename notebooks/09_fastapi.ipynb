# %%
import sys

print(sys.executable)
# Out:
# d:\DIVY\CODING\PURECODING\AI-ML\Week9\Devops\JobClarity\.venv\Scripts\python.exe

# %%
from pathlib import Path
import os

print(os.getcwd())

PROJECT_ROOT = Path.cwd().parent

print(PROJECT_ROOT)
# Out:
# d:\DIVY\CODING\PURECODING\AI-ML\Week9\Devops\JobClarity\notebooks
# d:\DIVY\CODING\PURECODING\AI-ML\Week9\Devops\JobClarity

# %%
import sys

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print(sys.path[:5])
# Out:
# ['d:\\DIVY\\CODING\\PURECODING\\AI-ML\\Week9\\Devops\\JobClarity', 'C:\\Program Files\\Python312\\python312.zip', 'C:\\Program Files\\Python312\\DLLs', 'C:\\Program Files\\Python312\\Lib', 'C:\\Program Files\\Python312']

# %%
import src.api.predictor
